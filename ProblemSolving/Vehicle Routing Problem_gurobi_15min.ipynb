# %% [markdown]
# # Capacitated Vehicle Routing Problem

# %% [markdown]
# ![Screenshot 2025-12-17 174810.png](attachment:5699091b-adbd-4c89-b31d-9772e45be317.png)

# %% [markdown]
# - $n$ is the number of clientes
# - $N$ is set of clients, with $N=\{1,2,...,n\}$
# - $V$ is set of vetices (or nodes), with $V=\{0\}\cup N$
# - $A$ is set of arcs, with $A=\{(i,j)\in V^2 : i\neq j\}$
# - $c_{ij}$ is cost of travel over arc $(i,j)\in A$
# - $Q$ is the vehicle capacity
# - $q_i$ is the amount that has to be delivered to customer $i\in N$
#
# Then, the formulation is the following
# $$\begin{align}
# \min \quad & \sum_{i,j\in A} c_{ij} x_{ij} \\
# \text{s.t.} \quad & \sum_{j\in V , j\neq i} x_{ij} = 1  && i \in N \\
# & \sum_{i\in V , i\neq j} x_{ij} = 1 && j \in N \\
# & \text{if} \ x_{ij}=1 \ \Rightarrow \ u_i + q_j = u_j && i,j \in A : j\neq 0, i\neq 0 \\
# & q_i \leq u_i \leq Q && i \in N \\
# & x_{ij} \in \{0,1\} && i,j \in A
# \end{align}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rnd = np.random
rnd.seed(0)

# %% [markdown]
# ```random.seed(0)``` sets the seed for the random number generator in Python's random module to a fixed value of 0. This ensures that the sequence of "random" numbers generated by functions like ```random.random()``` or ```random.randint()``` will be the same every time the program runs .

# %%
n = 20  # numbre of clients
xc = rnd.rand(n+1)*200
yc = rnd.rand(n+1)*100

# %%
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='b') #c- color, b- blue

# %%
N = [i for i in range(1, n+1)]
V = [0] + N #Union'+'
A = [(i, j) for i in V for j in V if i != j]

# %%
c = {(i, j): np.hypot(xc[i]-xc[j], yc[i]-yc[j]) for i, j in A}

# %% [markdown]
# What does this do?
#
# - Creates a dictionary
#
# - Keys → tuples (i, j)
#
# - Values → Euclidean distance between node i and node j
#
# ```np.hypot(a, b)``` computes: $\sqrt{a^2 + b^2}$
#
# - ```c[(i, j)]``` = **cost / distance** of traveling from node i to node j

# %%
Q = 20
q = {i: rnd.randint(1, 10) for i in N}

# %%
q
# Out:
# {1: 2,
#  2: 8,
#  3: 4,
#  4: 7,
#  5: 8,
#  6: 3,
#  7: 1,
#  8: 4,
#  9: 6,
#  10: 5,
#  11: 5,
#  12: 7,
#  13: 5,
#  14: 5,
#  15: 4,
#  16: 5,
#  17: 5,
#  18: 9,
#  19: 5,
#  20: 4}

# %%
from gurobipy import Model, GRB, quicksum

# %%
mdl = Model('CVRP') # Built a model named CVRP

# %%
x = mdl.addVars(A, vtype=GRB.BINARY)
u = mdl.addVars(N, vtype=GRB.CONTINUOUS)

# %% [markdown]
# Above creates a binary variable for each arc (i, j) ∈ A
#
# - Stored in a dictionary-like object x
# - ```x[i, j] = 1``` → vehicle travels directly from node ```i to node j```
# - ```x[i, j] = 0``` → vehicle does NOT travel from ```i to j```

# %%
mdl.modelSense = GRB.MINIMIZE
mdl.setObjective(quicksum(x[i, j]*c[i, j] for i, j in A))

# %%
mdl.addConstrs(quicksum(x[i, j] for j in V if j != i) == 1 for i in N)
mdl.addConstrs(quicksum(x[i, j] for i in V if i != j) == 1 for j in N)
mdl.addConstrs((x[i, j] == 1) >> (u[i]+q[j] == u[j])
               for i, j in A if i != 0 and j != 0)
mdl.addConstrs(u[i] >= q[i] for i in N)
mdl.addConstrs(u[i] <= Q for i in N)
# Out:
# {1: <gurobi.Constr *Awaiting Model Update*>,
#  2: <gurobi.Constr *Awaiting Model Update*>,
#  3: <gurobi.Constr *Awaiting Model Update*>,
#  4: <gurobi.Constr *Awaiting Model Update*>,
#  5: <gurobi.Constr *Awaiting Model Update*>,
#  6: <gurobi.Constr *Awaiting Model Update*>,
#  7: <gurobi.Constr *Awaiting Model Update*>,
#  8: <gurobi.Constr *Awaiting Model Update*>,
#  9: <gurobi.Constr *Awaiting Model Update*>,
#  10: <gurobi.Constr *Awaiting Model Update*>,
#  11: <gurobi.Constr *Awaiting Model Update*>,
#  12: <gurobi.Constr *Awaiting Model Update*>,
#  13: <gurobi.Constr *Awaiting Model Update*>,
#  14: <gurobi.Constr *Awaiting Model Update*>,
#  15: <gurobi.Constr *Awaiting Model Update*>,
#  16: <gurobi.Constr *Awaiting Model Update*>,
#  17: <gurobi.Constr *Awaiting Model Update*>,
#  18: <gurobi.Constr *Awaiting Model Update*>,
#  19: <gurobi.Constr *Awaiting Model Update*>,
#  20: <gurobi.Constr *Awaiting Model Update*>}

# %%
mdl.Params.MIPGap = 0.1
mdl.Params.TimeLimit = 900  # seconds
# Out:
# Set parameter MIPGap to value 0.1
# Set parameter TimeLimit to value 900

# %% [markdown]
# #### What is MIPGap?
#
# - Applies to **Mixed Integer Programming (MIP)** problems (like CVRP)
# - Measures how close the current solution is to the **best possible (optimal) solution**
#
# #### MIPGap Formula
#
# $$
# \text{MIPGap} =
# \frac{\text{Best Objective} - \text{Best Bound}}
# {|\text{Best Objective}|}
# $$
#
#
# #### What does `0.1` mean?
#
# - `0.1` = **10% optimality gap**
# - Gurobi will **stop early** if it finds a solution within **10% of optimal**
#
# #### Trade-off
#
# -  Faster solution
# -  May not be perfectly optimal

# %%
mdl.optimize()
# Out:
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  900
# MIPGap  0.1
#
# Optimize a model with 80 rows, 440 columns and 840 nonzeros (Min)
# Model fingerprint: 0xd8dff280
# Model has 420 linear objective coefficients
# Model has 380 simple general constraints
#   380 INDICATOR
# Variable types: 20 continuous, 420 integer (420 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   GenCon rhs range [1e+00, 9e+00]
#   GenCon coe range [1e+00, 1e+00]
# Presolve added 572 rows and 76 columns
# Presolve time: 0.04s
# Presolved: 652 rows, 516 columns, 2868 nonzeros
# Variable types: 96 continuous, 420 integer (420 binary)
# Found heuristic solution: objective 2540.4720602
# Found heuristic solution: objective 2454.9075993
# Found heuristic solution: objective 2392.4141498
#
# Root relaxation: objective 4.641926e+02, 122 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
#  2883961 1520426  914.10848   62   31  926.68462  808.78792  12.7%  20.7  825s
#  2899901 1527092  866.52395   49   46  926.68462  808.89299  12.7%  20.7  830s
#  2912687 1533470  873.05275   75   36  926.68462  808.98601  12.7%  20.7  835s
#  2927392 1539595 infeasible   67       926.68462  809.08653  12.7%  20.7  840s
#  2943065 1546204  851.43906   63   30  926.68462  809.19846  12.7%  20.7  845s
#  2956846 1552375  847.90868   47   39  926.68462  809.29854  12.7%  20.7  850s
#  2968955 1558307  815.97029   46   28  926.68462  809.38705  12.7%  20.7  855s
#  2980096 1563137  843.53219   46   13  926.68462  809.46370  12.6%  20.7  860s
#  2993504 1569936  902.34435   39   21  926.68462  809.55469  12.6%  20.7  865s
#  3008847 1577746  877.94004   63   39  926.68462  809.66390  12.6%  20.7  870s
#  3020869 1583704  844.17368   62   41  926.68462  809.74658  12.6%  20.7  875s
#  3035410 1590780  849.31394   56   42  926.68462  809.85205  12.6%  20.7  880s
#  3051786 1597209  879.81821   45   38  926.68462  809.95440  12.6%  20.7  885s
#  3065063 1603438  919.95702   74   26  926.68462  810.05172  12.6%  20.7  890s
#  3078722 1609973  854.39073   57   37  926.68462  810.14377  12.6%  20.7  895s
#  3092050 1615469  847.54206   46   20  926.68462  810.23100  12.6%  20.7  900s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 1068
#   Implied bound: 40
#   Projected implied bound: 9
#   MIR: 263
#   Mixing: 6
#   StrongCG: 12
#   Flow cover: 485
#   GUB cover: 24
#   Inf proof: 11
#   Zero half: 15
#   RLT: 1
#   Relax-and-lift: 25
#
# Explored 3092359 nodes (63933822 simplex iterations) in 900.07 seconds (497.25 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 10: 926.685 927.407 951.109 ... 1009.67
#
# Time limit reached
# Warning: max constraint violation (2.1000e-05) exceeds tolerance
# Warning: max general constraint violation (2.1000e-05) exceeds tolerance
# Best objective 9.266846212782e+02, best bound 8.102311083075e+02, gap 12.5667%

# %%
active_arcs = [a for a in A if x[a].x > 0.99]  ## it is x==1, but for some calculation reasons take x>0.99

# %%
active_arcs
# Out:
# [(0, 1),
#  (0, 2),
#  (0, 4),
#  (0, 7),
#  (0, 15),
#  (0, 18),
#  (1, 5),
#  (2, 0),
#  (3, 9),
#  (4, 11),
#  (5, 3),
#  (6, 0),
#  (7, 20),
#  (8, 13),
#  (9, 0),
#  (10, 17),
#  (11, 12),
#  (12, 0),
#  (13, 19),
#  (14, 16),
#  (15, 14),
#  (16, 6),
#  (17, 0),
#  (18, 10),
#  (19, 0),
#  (20, 8)]

# %%
for i, j in active_arcs:
    plt.plot([xc[i], xc[j]], [yc[i], yc[j]], c='g', zorder=0)
plt.plot(xc[0], yc[0], c='r', marker='s')
plt.scatter(xc[1:], yc[1:], c='b')

# %% [markdown]
# #### Conclusion :
# - **Best objective:** 9.266846212782e+02
# - **Best bound:** 8.102311083075e+02
# - **Gap:** 12.5667%
